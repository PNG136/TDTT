# %% [markdown]
# W2A1

# %%
print('Hello World')
# Out:
# Hello World

# %% [markdown]
# W2A2

# %%
a=input('nhập tên người dùng: ')
print('chào '+a)
# Out:
# chào phuong

# %% [markdown]
# W2A3

# %%
a=int(input('nhập 1 số nguyên: '))
b=int(input('nhập 1 số nguyên: '))
print('tổng là: '+ str(a+b))
print('hiệu là: '+ str(a-b))
print('tích là: '+ str(a*b))
print('thương là: '+ str(round(a/b,2)))
print('phần dư là: '+ str(a%b))
print('phan nguyên là: '+ str(a//b))
# Out:
# tổng là: 470
# hiệu là: -222
# tích là: 42904
# thương là: 0.36
# phần dư là: 124
# phan nguyên là: 0

# %% [markdown]
# W2A4

# %%
a1,b1,c1,a2,b2,a3=input('nhập điểm: ').split()
print('diem trung bình là: '+ str(round((float(a1)+float(b1)+float(c1)+2*float(a2)+2*float(b2)+3*float(a3))/6,1)))
# Out:
# diem trung bình là: 7.8

# %% [markdown]
# W2A5

# %%
a=int(input('nhập 1 số nguyên: '))
b=int(input('nhập 1 số nguyên: '))
print('luy thừa là: '+ str(a**b))
# Out:
# luy thừa là: 32

# %% [markdown]
# W2A6

# %%
a=input('nhập 1 chữ cái in thường: ')
print(ord(a),a.upper(),sep='\n')
# Out:
# 114
# R

# %% [markdown]
# W2A7

# %%
print('A = '+ str((13**2)*3+5))
print('B = '+ str(13**2*3+5))

# %% [markdown]
# W2A8

# %%
a=float(input('nhiệt độ Celcius: '))
print('F ='+str(9/5*a+32))
# Out:
# F =98.60000000000001

# %% [markdown]
# W2A9

# %%
x=float(input('nhập giá tiền đồng hồ: '))
print('tổng tiền :' +str(round(x*1.4,2)))
# Out:
# tong tien :14.0

# %% [markdown]
# W2A10

# %%
a,b,c=input('nhập tên 3 người: ').split()
print('Hi '+ a + ', ' + b + ' and ' + c + '.')
# Out:
# Hi phuong, thao and hoa.

# %% [markdown]
# W2A11

# %%
a=input('nhập số giờ: ')
b=input('nhập số phút: ')
print(str(int(a)*3600+int(b)*60)+'s')
# Out:
# 10560s

# %% [markdown]
# W2A12

# %%
n=int(input('nhập độ dài cạnh khối rubik: '))
print(6*n*n)
# Out:
# 216

# %% [markdown]
# W2A13

# %%
a=int(input('nhập 1 số nguyên dương: '))
b=int(input('nhập 1 số nguyên dương: '))
print(str(a*b)[len(str(a*b))-1])
# Out:
# 6

# %% [markdown]
# W2A14

# %%
a=int(input('nhập số: '))
b=int(input('nhập số: '))
a,b=b,a
print('a = '+str(a))
print('b = '+str(b))
# Out:
# a = 5
# b = 1

# %% [markdown]
# W2A15

# %%
n=int(input('nhập 1 số nguyên dương n: '))
print(6*n*(n-1)+1)
# Out:
# 181

# %% [markdown]
# W2A16

# %%
print('Spring\nSummer\nAutumn\nWinter')
# Out:
# Spring
# Summer
# Autumn
# Winter

# %% [markdown]
# W2A17

# %%
print('*')
print('***')
print('*****')
# Out:
# *
# ***
# *****

# %% [markdown]
# W2A18

# %%
print("###  ##   ### ###")
print(" #   # #   #   # ")
print(" #   # #   #   # ")
print(" #   # #   #   # ")
print(" #   ##    #   # ")

# %% [markdown]
# W2A19

# %%
print('Monday\nThuesday\nWednesday\nThursday\nFriday\nSaturday\nSunday')
# Out:
# Monday
# Thuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday

# %% [markdown]
# W2A20

# %%
print('Jannury\nFebruary\nMarch\nApril\nMay\nJune\nJuly\nAugust\nSeptember\nOctober\nNovember\nDecember')
# Out:
# Jannury
# February
# March
# April
# May
# June
# July
# August
# September
# October
# November
# December

# %% [markdown]
# W2A21

# %%
for i in range(10):
    print('Hello World')
# Out:
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
