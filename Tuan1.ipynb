# %% [markdown]
# Bài 1

# %%
a=int(input())
print(a*2)
# Out:
# 107151754

# %% [markdown]
# BÀI 2

# %%
a=float(input())
b=float(input())
print(round(min(a,b)**2*3.14,2))
# Out:
# 1455973078.79

# %% [markdown]
# Bài 3

# %%
a=input()
b=a.upper()
if b!=a:
    print(b)
else:
    print(a.lower())
# Out:
# v

# %% [markdown]
# Bài 4

# %%
a=input()
if ('a' <= a <= 'z') or ('A' <= a <= 'Z'):
    print(a + " là kí tự alphabet")
else:
    print(a + " không phải là kí tự alphabet")
# Out:
# j là kí tự alphabet

# %% [markdown]
# Bài 5

# %%
a=input()
if a=='a' or a=='A':
    print(a)
else:
    print(chr(ord(a)-1))
# Out:
# F

# %% [markdown]
# Bài 6

# %%
a=float(input())
b=float(input())
c=float(input())
if a+b>c and a+c>b and b+c>a:
    print(round(a*b*c, 1))
else:
    print("không phải 3 cạnh của tam giác")
# Out:
# 65.7

# %% [markdown]
# Bài 7

# %%
a=input()
print(a[4],a[8],sep='\n')
# Out:
# 7
# 4

# %% [markdown]
# Bìa 8

# %%
a=input()
b=float(input('số điện tháng trước'))
c=float(input('số điện tháng này'))
k=c-b
if k<=50:
    print(k*1.984)
if k<=100:
    print(50*1.984+(k-50)*2.050)
if k<=200:
    print(50*1.984+50*2.050+(k-100)*2.380)
if k<=300:
    print(50*1.984+50*2.050+100*2.380+(k-200)*2.998)
if k<=400:
    print(50*1.984+50*2.050+100*2.380+100*2.998+(k-300)*3.350)
if k>=401:
    print(50*1.984+50*2.050+100*2.380+100*2.998+100*3.350+(k-400)*3.460)

# %% [markdown]
# Bài 1 EX

# %%
a=int(input())
if a%2==0:
    print("số chẵn")
else:    
    print("số lẻ")

# %% [markdown]
# Bài 2 EX

# %%
a=int(input())
if str(a)[len(str(a))-1] =='5':
    print (True)
else:
    print(False)
# Out:
# True

# %% [markdown]
# Bài 3 EX

# %%
a=int(input())
if a%15==0:
    print(True)
else:
    print(False)
# Out:
# True

# %% [markdown]
# Bài 4 EX

# %%
a=int(input())
if 2026-a>=18:
    print("đủ tuổi bầu cử")
else:
    print("không đủ tuổi bầu cử")
# Out:
# 9

# %% [markdown]
# Bài 5 EX

# %%
a=int(input())
b=int(input())
if a==b:
    print("hai số bằng nhau")
else:
    print (max(a,b))

# %% [markdown]
# Bài 6 EX

# %%
a=input()
if 'a'<=a<='z' or 'A'<=a<='Z':
    print("kí tự alphabet")
if '0'<=a<='9':
    print("kí tự số")

# %% [markdown]
# Bài 7 EX

# %%
a=float(input())
if a>=8:
    print("điểm giỏi")
elif 8>a>=6.5:
    print("điểm khá")
elif 6.5>a>=5:
    print("điểm trung bình")
else:    
    print("điểm yếu")

# %% [markdown]
# Bài 8 EX

# %%
a=int(input())
if a%4==0 and a%100!=0 or a%400==0:
    print("năm nhuận")
else:
    print("năm không nhuận")

# %% [markdown]
# Bài 9 EX

# %%
a=int(input())
dic={0:'không',1:'một',2:'hai',3:'ba',4:'bốn',5:'năm',6:'sáu',7:'bảy',8:'tám',9:'chín'}
print(dic[a])

# %% [markdown]
# Bài 10 EX

# %%
a=float(input())
if a>4:
    print("Qua môn")
else:
    print("Học lại")

# %% [markdown]
# Bài 11 EX

# %%
a=int(input('năm hiện tại'))
b=int(input('năm sinh'))
if a-b>=18:
    print("đủ 18 tuổi")
else:
    print("không đủ 18 tuổi")
